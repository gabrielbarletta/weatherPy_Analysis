# %% [markdown]
# ## Deliverable 1

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/gabrielbarletta/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/gabrielbarletta/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Module 6.1.1 Create and clone a git repository
# Module 6.1.2 Overview of the project
# Module 6.1.3 Review the Geoqrphic Coordinate System (Latitude and Longitude)

# %%
# Insure your API keys remain secure by adding config.py to the .gitigore file in your repository
# see end of module 6.2.7

# %%
# import dependencies (python Libraries)
# Module 6.1.4 Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# add citipy library
from citipy import citipy 

# add requests module
import requests

# Import the API key from config. py file
from config import weather_api_key

# import datetime to recast api date a datetime format
import time 
from datetime import datetime

# %%
# Module 6.1.4 Generate Random Latitude (Lats) and Longitude (Lngs)
# Note: Lats range from -90 to 90
# Note: Lngs range from -180 to 180


# From 6.1.4 - Create a set of random Latitude and Longitude combinations.
# Note for our inital work set the size to just 10 until we get the entire code working
# this will limit the number of calls we make to OpenWeatherAPI as there is a
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# the zip method combines the lats and lngs into a list of pairs
lat_lngs = zip(lats, lngs)
lat_lngs


# Add the latitudes and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Module 6.1.5 Generate Random World Cities
# This will require citipy to be installed to the PythonData Environment
# this will require a pip install of citipy

# Use the citipy module to determine city based on Latitude and Longitude.
# add from citipy import citipy to the List of dependencies imported in second

# Create a List for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
#6.2.6
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

#check to see if the request.get worked
#print(requests.get(city_url).json())

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | boke
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | galle
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | dalby
# Processing Record 11 of Set 1 | port macquarie
# Processing Record 12 of Set 1 | gusinoye ozero
# Processing Record 13 of Set 1 | vierzon
# Processing Record 14 of Set 1 | prince george
# Processing Record 15 of Set 1 | whitehorse
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | merrill
# Processing Record 18 of Set 1 | ukiah
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | sao jose da coroa grande
# Processing Record 24 of Set 1 | vanavara
# Processing Record 25 of Set 1 | erhlin
# City not found. Skipping...
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | prince rupert
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | port hedland
# Processing Record 32 of Set 1 | manggar
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | kiri buru
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | pacific grove
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | george town
# Processing Record 39 of Set 1 | baton rouge
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | zyryanka
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | araouane
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | charlestown
# Processing Record 48 of Set 1 | pokhara
# Processing Record 49 of Set 1 | kochevo
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 2 of Set 2 | grand-santi
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | tallahassee
# Processing Record 6 of Set 2 | nordfjordeid
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | ust-nera
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | vrangel
# Processing Record 15 of Set 2 | nagato
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | nortelandia
# Processing Record 18 of Set 2 | nanortalik
# Processing Record 19 of Set 2 | kangaatsiaq
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | santa cruz
# Processing Record 22 of Set 2 | antofagasta
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | grindavik
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | komsomolskiy
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | husavik
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 2 | mildura
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | akureyri
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | soller
# Processing Record 39 of Set 2 | san quintin
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | alice springs
# Processing Record 42 of Set 2 | shingu
# Processing Record 43 of Set 2 | dongying
# Processing Record 44 of Set 2 | carutapera
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | clyde river
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | abu samrah
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | saint anthony
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | abulug
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | shahreza
# Processing Record 6 of Set 3 | is
# City not found. Skipping...
# Processing Record 7 of Set 3 | mayo
# Processing Record 8 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 3 | payo
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | hobyo
# Processing Record 12 of Set 3 | fortuna
# Processing Record 13 of Set 3 | sumbe
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | berbera
# Processing Record 17 of Set 3 | cabra
# Processing Record 18 of Set 3 | poladpur
# Processing Record 19 of Set 3 | vardo
# Processing Record 20 of Set 3 | guanica
# Processing Record 21 of Set 3 | nushki
# Processing Record 22 of Set 3 | alofi
# Processing Record 23 of Set 3 | provideniya
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | laguna
# Processing Record 26 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | sechura
# Processing Record 30 of Set 3 | tungor
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | pangnirtung
# Processing Record 33 of Set 3 | okhotsk
# Processing Record 34 of Set 3 | sao joao da barra
# Processing Record 35 of Set 3 | lompoc
# Processing Record 36 of Set 3 | sorland
# Processing Record 37 of Set 3 | jutai
# Processing Record 38 of Set 3 | las choapas
# Processing Record 39 of Set 3 | camacha
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 3 | nizwa
# Processing Record 43 of Set 3 | totness
# Processing Record 44 of Set 3 | saint-pierre
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | raudeberg
# Processing Record 49 of Set 3 | parole
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | gremyachinsk
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | kahului
# Processing Record 6 of Set 4 | asnaes
# Processing Record 7 of Set 4 | halifax
# Processing Record 8 of Set 4 | port lincoln
# Processing Record 9 of Set 4 | santa maria
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | hithadhoo
# Processing Record 14 of Set 4 | oranjemund
# Processing Record 15 of Set 4 | pimenteiras
# Processing Record 16 of Set 4 | aguimes
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | hirara
# Processing Record 19 of Set 4 | bolshoy kamen
# Processing Record 20 of Set 4 | rathcoole
# Processing Record 21 of Set 4 | stolin
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | dolores
# Processing Record 24 of Set 4 | seoul
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | shelburne
# Processing Record 27 of Set 4 | salalah
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | lexington
# Processing Record 30 of Set 4 | cabedelo
# Processing Record 31 of Set 4 | acapulco
# Processing Record 32 of Set 4 | pedasi
# Processing Record 33 of Set 4 | opunake
# Processing Record 34 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 35 of Set 4 | yarada
# Processing Record 36 of Set 4 | half moon bay
# Processing Record 37 of Set 4 | honiton
# Processing Record 38 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 4 | kattivakkam
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | cassilandia
# Processing Record 42 of Set 4 | mutoko
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | mogadishu
# Processing Record 45 of Set 4 | larsnes
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | myre
# Processing Record 48 of Set 4 | great falls
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | saint-francois
# Processing Record 1 of Set 5 | mao
# Processing Record 2 of Set 5 | babati
# Processing Record 3 of Set 5 | sinop
# Processing Record 4 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 5 | manbij
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | tabas
# Processing Record 9 of Set 5 | matara
# Processing Record 10 of Set 5 | atuona
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | marawi
# Processing Record 13 of Set 5 | santa catarina de tepehuanes
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | khetia
# Processing Record 16 of Set 5 | urumqi
# Processing Record 17 of Set 5 | rocha
# Processing Record 18 of Set 5 | mandalgovi
# Processing Record 19 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 5 | key west
# Processing Record 21 of Set 5 | ulagan
# Processing Record 22 of Set 5 | chuy
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | bassano
# Processing Record 25 of Set 5 | haines junction
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | denpasar
# Processing Record 28 of Set 5 | nago
# Processing Record 29 of Set 5 | gazli
# Processing Record 30 of Set 5 | rancho palos verdes
# Processing Record 31 of Set 5 | las vegas
# Processing Record 32 of Set 5 | namtsy
# Processing Record 33 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 5 | melo
# Processing Record 35 of Set 5 | deputatskiy
# Processing Record 36 of Set 5 | gat
# Processing Record 37 of Set 5 | shebalino
# Processing Record 38 of Set 5 | hilo
# Processing Record 39 of Set 5 | vila velha
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | eureka
# Processing Record 43 of Set 5 | teguise
# Processing Record 44 of Set 5 | puerto ayora
# Processing Record 45 of Set 5 | la romana
# Processing Record 46 of Set 5 | mitsamiouli
# Processing Record 47 of Set 5 | qaqortoq
# Processing Record 48 of Set 5 | celestun
# Processing Record 49 of Set 5 | maba
# Processing Record 50 of Set 5 | palora
# Processing Record 1 of Set 6 | westport
# Processing Record 2 of Set 6 | teluk nibung
# Processing Record 3 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 5 of Set 6 | phalaborwa
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | puerto leguizamo
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | los llanos de aridane
# Processing Record 10 of Set 6 | shihezi
# Processing Record 11 of Set 6 | ballina
# Processing Record 12 of Set 6 | jaciara
# Processing Record 13 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 6 | koslan
# Processing Record 15 of Set 6 | quebo
# Processing Record 16 of Set 6 | la tuque
# Processing Record 17 of Set 6 | mugumu
# Processing Record 18 of Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 19 of Set 6 | beyla
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | twin falls
# Processing Record 22 of Set 6 | yerkoy
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | kuah
# Processing Record 25 of Set 6 | bom jesus
# Processing Record 26 of Set 6 | karratha
# Processing Record 27 of Set 6 | paka
# Processing Record 28 of Set 6 | smithers
# Processing Record 29 of Set 6 | georgetown
# Processing Record 30 of Set 6 | sabha
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | camana
# Processing Record 33 of Set 6 | teeswater
# Processing Record 34 of Set 6 | mestia
# Processing Record 35 of Set 6 | hay river
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | cornwall
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | lloydminster
# Processing Record 40 of Set 6 | quatre cocos
# Processing Record 41 of Set 6 | toppenish
# Processing Record 42 of Set 6 | terrace bay
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | ningyang
# Processing Record 45 of Set 6 | takahashi
# Processing Record 46 of Set 6 | taseyevo
# Processing Record 47 of Set 6 | kapitanivka
# Processing Record 48 of Set 6 | port augusta
# Processing Record 49 of Set 6 | necochea
# Processing Record 50 of Set 6 | okha
# Processing Record 1 of Set 7 | axim
# Processing Record 2 of Set 7 | bonthe
# Processing Record 3 of Set 7 | xinmin
# Processing Record 4 of Set 7 | abay
# Processing Record 5 of Set 7 | geraldton
# Processing Record 6 of Set 7 | kavaratti
# Processing Record 7 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | conceicao do araguaia
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | soc trang
# Processing Record 12 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 7 | flinders
# Processing Record 14 of Set 7 | palmerston north
# Processing Record 15 of Set 7 | paamiut
# Processing Record 16 of Set 7 | yuyao
# Processing Record 17 of Set 7 | tual
# Processing Record 18 of Set 7 | juneau
# Processing Record 19 of Set 7 | qujing
# Processing Record 20 of Set 7 | teguldet
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | kibaya
# Processing Record 23 of Set 7 | vryburg
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | nassau
# Processing Record 26 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 7 | pontes e lacerda
# Processing Record 29 of Set 7 | bacungan
# Processing Record 30 of Set 7 | antalaha
# Processing Record 31 of Set 7 | lokosovo
# Processing Record 32 of Set 7 | mahebourg
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | henties bay
# Processing Record 35 of Set 7 | helong
# Processing Record 36 of Set 7 | asau
# Processing Record 37 of Set 7 | laguna de perlas
# Processing Record 38 of Set 7 | sibolga
# Processing Record 39 of Set 7 | nola
# Processing Record 40 of Set 7 | dunmore town
# Processing Record 41 of Set 7 | iranshahr
# Processing Record 42 of Set 7 | coron
# Processing Record 43 of Set 7 | klyuchi
# Processing Record 44 of Set 7 | turukhansk
# Processing Record 45 of Set 7 | talgar
# Processing Record 46 of Set 7 | goure
# Processing Record 47 of Set 7 | imbituba
# Processing Record 48 of Set 7 | gariaband
# Processing Record 49 of Set 7 | talcahuano
# Processing Record 50 of Set 7 | lincoln
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | talnakh
# Processing Record 3 of Set 8 | general pico
# Processing Record 4 of Set 8 | russell
# Processing Record 5 of Set 8 | shu
# Processing Record 6 of Set 8 | kikwit
# Processing Record 7 of Set 8 | coihaique
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | waingapu
# Processing Record 10 of Set 8 | mezhdurechensk
# Processing Record 11 of Set 8 | lamu
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | campos belos
# Processing Record 14 of Set 8 | omboue
# Processing Record 15 of Set 8 | takoradi
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | samarai
# Processing Record 18 of Set 8 | lufilufi
# Processing Record 19 of Set 8 | igrim
# Processing Record 20 of Set 8 | marsh harbour
# Processing Record 21 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | rio cuarto
# Processing Record 25 of Set 8 | ternate
# Processing Record 26 of Set 8 | safaga
# Processing Record 27 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 8 | poronaysk
# Processing Record 29 of Set 8 | ibra
# Processing Record 30 of Set 8 | boguchany
# Processing Record 31 of Set 8 | sai buri
# Processing Record 32 of Set 8 | caravelas
# Processing Record 33 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 8 | zonguldak
# Processing Record 35 of Set 8 | port blair
# Processing Record 36 of Set 8 | walvis bay
# Processing Record 37 of Set 8 | inhambane
# Processing Record 38 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 8 | lazaro cardenas
# Processing Record 40 of Set 8 | ayan
# Processing Record 41 of Set 8 | darab
# Processing Record 42 of Set 8 | jinchang
# Processing Record 43 of Set 8 | codrington
# Processing Record 44 of Set 8 | jalu
# Processing Record 45 of Set 8 | kirkland lake
# Processing Record 46 of Set 8 | buala
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | san patricio
# Processing Record 49 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 8 | port shepstone
# Processing Record 1 of Set 9 | saint george
# Processing Record 2 of Set 9 | elko
# Processing Record 3 of Set 9 | oktyabrskiy
# Processing Record 4 of Set 9 | ust-maya
# Processing Record 5 of Set 9 | mbour
# Processing Record 6 of Set 9 | riyadh
# Processing Record 7 of Set 9 | sulmona
# Processing Record 8 of Set 9 | cidreira
# Processing Record 9 of Set 9 | bejar
# Processing Record 10 of Set 9 | koshurnikovo
# Processing Record 11 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 9 | mattru
# Processing Record 13 of Set 9 | mamlyutka
# Processing Record 14 of Set 9 | jati
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | naze
# Processing Record 17 of Set 9 | abnub
# Processing Record 18 of Set 9 | dingle
# Processing Record 19 of Set 9 | adrar
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | ridgecrest
# Processing Record 22 of Set 9 | uaua
# Processing Record 23 of Set 9 | bonfim
# Processing Record 24 of Set 9 | rio gallegos
# Processing Record 25 of Set 9 | dudinka
# Processing Record 26 of Set 9 | wattegama
# Processing Record 27 of Set 9 | sao miguel do araguaia
# Processing Record 28 of Set 9 | norrtalje
# Processing Record 29 of Set 9 | bam
# Processing Record 30 of Set 9 | atar
# Processing Record 31 of Set 9 | blarney
# Processing Record 32 of Set 9 | lingyuan
# Processing Record 33 of Set 9 | wajima
# Processing Record 34 of Set 9 | ponta delgada
# Processing Record 35 of Set 9 | aleksandrovka
# Processing Record 36 of Set 9 | price
# Processing Record 37 of Set 9 | goksun
# Processing Record 38 of Set 9 | warrnambool
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | micheweni
# Processing Record 41 of Set 9 | severo-kurilsk
# Processing Record 42 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 9 | jumla
# Processing Record 44 of Set 9 | norman wells
# Processing Record 45 of Set 9 | tevaitoa
# Processing Record 46 of Set 9 | zyryanovsk
# Processing Record 47 of Set 9 | tagusao
# Processing Record 48 of Set 9 | tari
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | wilmington
# Processing Record 1 of Set 10 | nueva loja
# Processing Record 2 of Set 10 | meadow lake
# Processing Record 3 of Set 10 | kawhia
# Processing Record 4 of Set 10 | golpayegan
# Processing Record 5 of Set 10 | najran
# Processing Record 6 of Set 10 | stromness
# Processing Record 7 of Set 10 | verkhnyaya inta
# Processing Record 8 of Set 10 | marion
# Processing Record 9 of Set 10 | ascension
# Processing Record 10 of Set 10 | yaan
# Processing Record 11 of Set 10 | boone
# Processing Record 12 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 13 of Set 10 | alyangula
# Processing Record 14 of Set 10 | petatlan
# Processing Record 15 of Set 10 | tadine
# Processing Record 16 of Set 10 | porto novo
# Processing Record 17 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 18 of Set 10 | santo antonio do ica
# Processing Record 19 of Set 10 | abha
# Processing Record 20 of Set 10 | utiel
# Processing Record 21 of Set 10 | zaysan
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | mushie
# Processing Record 24 of Set 10 | talara
# Processing Record 25 of Set 10 | zhangjiakou
# Processing Record 26 of Set 10 | kamina
# Processing Record 27 of Set 10 | chicama
# Processing Record 28 of Set 10 | solnechnyy
# Processing Record 29 of Set 10 | jerusalem
# Processing Record 30 of Set 10 | vuktyl
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | polyarnyy
# Processing Record 33 of Set 10 | san vicente
# Processing Record 34 of Set 10 | guerrero negro
# Processing Record 35 of Set 10 | mahibadhoo
# Processing Record 36 of Set 10 | srivardhan
# Processing Record 37 of Set 10 | morro bay
# Processing Record 38 of Set 10 | esperance
# Processing Record 39 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 10 | belomorsk
# Processing Record 41 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 10 | mehamn
# Processing Record 43 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 10 | lukovetskiy
# Processing Record 45 of Set 10 | tinqueux
# Processing Record 46 of Set 10 | hasaki
# Processing Record 47 of Set 10 | tessalit
# Processing Record 48 of Set 10 | ahuimanu
# Processing Record 49 of Set 10 | khasan
# Processing Record 50 of Set 10 | sennoy
# Processing Record 1 of Set 11 | sorada
# Processing Record 2 of Set 11 | osinki
# Processing Record 3 of Set 11 | mahina
# Processing Record 4 of Set 11 | craig
# Processing Record 5 of Set 11 | monrovia
# Processing Record 6 of Set 11 | beloha
# Processing Record 7 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 11 | haicheng
# Processing Record 9 of Set 11 | junin
# Processing Record 10 of Set 11 | svarstad
# Processing Record 11 of Set 11 | slovenske konjice
# Processing Record 12 of Set 11 | aksu
# Processing Record 13 of Set 11 | lata
# Processing Record 14 of Set 11 | zhezkazgan
# Processing Record 15 of Set 11 | rosarito
# Processing Record 16 of Set 11 | ngunguru
# Processing Record 17 of Set 11 | merauke
# Processing Record 18 of Set 11 | mackenzie
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | opotiki
# Processing Record 21 of Set 11 | ati
# Processing Record 22 of Set 11 | buta
# Processing Record 23 of Set 11 | puerto madryn
# Processing Record 24 of Set 11 | zilair
# Processing Record 25 of Set 11 | cascais
# Processing Record 26 of Set 11 | port keats
# Processing Record 27 of Set 11 | tongren
# Processing Record 28 of Set 11 | mian channun
# Processing Record 29 of Set 11 | edd
# Processing Record 30 of Set 11 | palmer
# Processing Record 31 of Set 11 | aasiaat
# Processing Record 32 of Set 11 | kruisfontein
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | yumen
# Processing Record 35 of Set 11 | noumea
# Processing Record 36 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 11 | calvinia
# Processing Record 38 of Set 11 | sao borja
# Processing Record 39 of Set 11 | plettenberg bay
# Processing Record 40 of Set 11 | narsaq
# Processing Record 41 of Set 11 | krasnaya gorka
# Processing Record 42 of Set 11 | kushiro
# Processing Record 43 of Set 11 | nioki
# Processing Record 44 of Set 11 | inuvik
# Processing Record 45 of Set 11 | bangsund
# Processing Record 46 of Set 11 | rybachiy
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | bana
# Processing Record 49 of Set 11 | sibiti
# Processing Record 50 of Set 11 | marsa matruh
# Processing Record 1 of Set 12 | awjilah
# Processing Record 2 of Set 12 | lagos
# Processing Record 3 of Set 12 | kiama
# Processing Record 4 of Set 12 | kiruna
# Processing Record 5 of Set 12 | waipawa
# Processing Record 6 of Set 12 | rezekne
# Processing Record 7 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 12 | gravdal
# Processing Record 9 of Set 12 | uni
# Processing Record 10 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 12 | muisne
# Processing Record 12 of Set 12 | santa marta de tormes
# Processing Record 13 of Set 12 | nemuro
# Processing Record 14 of Set 12 | soyo
# Processing Record 15 of Set 12 | tumen
# Processing Record 16 of Set 12 | katima mulilo
# Processing Record 17 of Set 12 | omsukchan
# Processing Record 18 of Set 12 | biak
# Processing Record 19 of Set 12 | lake havasu city
# Processing Record 20 of Set 12 | linxia
# Processing Record 21 of Set 12 | yerbogachen
# Processing Record 22 of Set 12 | luga
# Processing Record 23 of Set 12 | mozhaysk
# Processing Record 24 of Set 12 | wasilla
# Processing Record 25 of Set 12 | te anau
# Processing Record 26 of Set 12 | damaturu
# Processing Record 27 of Set 12 | bijie
# Processing Record 28 of Set 12 | sayat
# Processing Record 29 of Set 12 | polczyn-zdroj
# Processing Record 30 of Set 12 | hovd
# Processing Record 31 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 32 of Set 12 | goya
# Processing Record 33 of Set 12 | mansa
# Processing Record 34 of Set 12 | poum
# Processing Record 35 of Set 12 | touros
# Processing Record 36 of Set 12 | manakara
# Processing Record 37 of Set 12 | atambua
# Processing Record 38 of Set 12 | katobu
# Processing Record 39 of Set 12 | saryg-sep
# Processing Record 40 of Set 12 | yeroham
# Processing Record 41 of Set 12 | askino
# Processing Record 42 of Set 12 | worland
# Processing Record 43 of Set 12 | kasongo-lunda
# Processing Record 44 of Set 12 | camalu
# Processing Record 45 of Set 12 | antigonish
# Processing Record 46 of Set 12 | dengfeng
# Processing Record 47 of Set 12 | korsakov
# Processing Record 48 of Set 12 | anchorage
# Processing Record 49 of Set 12 | verkhnevilyuysk
# Processing Record 50 of Set 12 | ilulissat
# Processing Record 1 of Set 13 | pangkalanbuun
# Processing Record 2 of Set 13 | harstad
# Processing Record 3 of Set 13 | havre-saint-pierre
# Processing Record 4 of Set 13 | bella union
# Processing Record 5 of Set 13 | inverell
# Processing Record 6 of Set 13 | brigham city
# Processing Record 7 of Set 13 | malibu
# Processing Record 8 of Set 13 | baykit
# Processing Record 9 of Set 13 | masyaf
# Processing Record 10 of Set 13 | tigil
# Processing Record 11 of Set 13 | sultanpur
# Processing Record 12 of Set 13 | zhigansk
# Processing Record 13 of Set 13 | portobelo
# Processing Record 14 of Set 13 | mnogovershinnyy
# Processing Record 15 of Set 13 | huarmey
# Processing Record 16 of Set 13 | winslow
# Processing Record 17 of Set 13 | porto seguro
# Processing Record 18 of Set 13 | eregli
# Processing Record 19 of Set 13 | luocheng
# Processing Record 20 of Set 13 | iaciara
# Processing Record 21 of Set 13 | puro
# Processing Record 22 of Set 13 | trincomalee
# Processing Record 23 of Set 13 | avila
# Processing Record 24 of Set 13 | batagay-alyta
# Processing Record 25 of Set 13 | teknaf
# Processing Record 26 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 13 | manat
# Processing Record 28 of Set 13 | alva
# Processing Record 29 of Set 13 | kazanskaya
# Processing Record 30 of Set 13 | meulaboh
# Processing Record 31 of Set 13 | thinadhoo
# Processing Record 32 of Set 13 | nhulunbuy
# Processing Record 33 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 13 | kaeo
# Processing Record 35 of Set 13 | ciudad bolivar
# Processing Record 36 of Set 13 | torquay
# Processing Record 37 of Set 13 | temamatla
# Processing Record 38 of Set 13 | arman
# Processing Record 39 of Set 13 | mlonggo
# Processing Record 40 of Set 13 | labuhan
# Processing Record 41 of Set 13 | baker city
# Processing Record 42 of Set 13 | tokur
# Processing Record 43 of Set 13 | finnsnes
# Processing Record 44 of Set 13 | oxford
# Processing Record 45 of Set 13 | maldonado
# Processing Record 46 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 13 | san cristobal
# Processing Record 49 of Set 13 | manokwari
# Processing Record 50 of Set 13 | sao jose
# Processing Record 1 of Set 14 | pitimbu
# Processing Record 2 of Set 14 | sal rei
# Processing Record 3 of Set 14 | shimoda
# Processing Record 4 of Set 14 | riberalta
# Processing Record 5 of Set 14 | mitzic
# Processing Record 6 of Set 14 | forestville
# Processing Record 7 of Set 14 | egvekinot
# Processing Record 8 of Set 14 | minab
# Processing Record 9 of Set 14 | warwick
# Processing Record 10 of Set 14 | kemijarvi
# Processing Record 11 of Set 14 | colares
# Processing Record 12 of Set 14 | tecoanapa
# Processing Record 13 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 14 | baiyin
# Processing Record 15 of Set 14 | ligayan
# Processing Record 16 of Set 14 | cape canaveral
# Processing Record 17 of Set 14 | itoman
# Processing Record 18 of Set 14 | nachalovo
# Processing Record 19 of Set 14 | muli
# Processing Record 20 of Set 14 | tateyama
# Processing Record 21 of Set 14 | gawler
# Processing Record 22 of Set 14 | barauna
# Processing Record 23 of Set 14 | augustow
# Processing Record 24 of Set 14 | puerto el triunfo
# Processing Record 25 of Set 14 | puerto escondido
# Processing Record 26 of Set 14 | bima
# Processing Record 27 of Set 14 | les cayes
# Processing Record 28 of Set 14 | vredefort
# Processing Record 29 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 14 | skelleftea
# Processing Record 31 of Set 14 | asyut
# Processing Record 32 of Set 14 | severo-yeniseyskiy
# Processing Record 33 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 14 | praia
# Processing Record 35 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 14 | peniche
# Processing Record 37 of Set 14 | ormara
# Processing Record 38 of Set 14 | bocaiuva
# Processing Record 39 of Set 14 | caxito
# Processing Record 40 of Set 14 | tsiroanomandidy
# Processing Record 41 of Set 14 | broken hill
# Processing Record 42 of Set 14 | ondjiva
# Processing Record 43 of Set 14 | xucheng
# Processing Record 44 of Set 14 | boa vista
# Processing Record 45 of Set 14 | betanzos
# Processing Record 46 of Set 14 | rawson
# Processing Record 47 of Set 14 | fukue
# Processing Record 48 of Set 14 | bilibino
# Processing Record 49 of Set 14 | laureles
# Processing Record 50 of Set 14 | tabou
# Processing Record 1 of Set 15 | montanhas
# Processing Record 2 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 15 | ambilobe
# Processing Record 4 of Set 15 | tezu
# Processing Record 5 of Set 15 | xining
# Processing Record 6 of Set 15 | eyl
# Processing Record 7 of Set 15 | rosetta
# Processing Record 8 of Set 15 | yen bai
# Processing Record 9 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 10 of Set 15 | madras
# Processing Record 11 of Set 15 | tortoli
# Processing Record 12 of Set 15 | gemena
# Processing Record 13 of Set 15 | padang
# Processing Record 14 of Set 15 | zhengjiatun
# Processing Record 15 of Set 15 | arak
# Processing Record 16 of Set 15 | doha
# Processing Record 17 of Set 15 | shumskiy
# Processing Record 18 of Set 15 | warri
# Processing Record 19 of Set 15 | quixada
# Processing Record 20 of Set 15 | boralday
# Processing Record 21 of Set 15 | nizhniy kuranakh
# Processing Record 22 of Set 15 | avera
# Processing Record 23 of Set 15 | jardim
# Processing Record 24 of Set 15 | hohhot
# Processing Record 25 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 15 | kodinar
# Processing Record 27 of Set 15 | sneek
# Processing Record 28 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 15 | strzelce opolskie
# Processing Record 30 of Set 15 | magadan
# Processing Record 31 of Set 15 | yurga
# Processing Record 32 of Set 15 | joshimath
# Processing Record 33 of Set 15 | makakilo city
# Processing Record 34 of Set 15 | gizo
# Processing Record 35 of Set 15 | saumur
# Processing Record 36 of Set 15 | college
# Processing Record 37 of Set 15 | moquegua
# Processing Record 38 of Set 15 | taltal
# Processing Record 39 of Set 15 | menongue
# Processing Record 40 of Set 15 | pacifica
# Processing Record 41 of Set 15 | vila
# Processing Record 42 of Set 15 | poso
# Processing Record 43 of Set 15 | esso
# Processing Record 44 of Set 15 | ayni
# Processing Record 45 of Set 15 | berlevag
# Processing Record 46 of Set 15 | evensk
# Processing Record 47 of Set 15 | sobolevo
# Processing Record 48 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 49 of Set 15 | barroualie
# City not found. Skipping...
# Processing Record 50 of Set 15 | pyaozerskiy
# Processing Record 1 of Set 16 | pamekasan
# Processing Record 2 of Set 16 | suruc
# Processing Record 3 of Set 16 | port-gentil
# Processing Record 4 of Set 16 | ferme-neuve
# Processing Record 5 of Set 16 | atikokan
# Processing Record 6 of Set 16 | catuday
# Processing Record 7 of Set 16 | kirakira
# Processing Record 8 of Set 16 | burnie
# Processing Record 9 of Set 16 | pederneiras
# Processing Record 10 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 16 | licheng
# Processing Record 12 of Set 16 | florina
# Processing Record 13 of Set 16 | campbellsville
# Processing Record 14 of Set 16 | murmino
# Processing Record 15 of Set 16 | kimbe
# Processing Record 16 of Set 16 | chalmette
# Processing Record 17 of Set 16 | khani
# Processing Record 18 of Set 16 | warrington
# Processing Record 19 of Set 16 | ishinomaki
# Processing Record 20 of Set 16 | launceston
# Processing Record 21 of Set 16 | ryotsu
# Processing Record 22 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 16 | quelimane
# Processing Record 24 of Set 16 | chapais
# Processing Record 25 of Set 16 | borogontsy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# module 6.2.7
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow  71.2906 -156.7887     12.22        79          90
# 1            Boke  10.9409  -14.2967     75.49        85          96
# 2         Rikitea -23.1203 -134.9692     76.69        73          98
# 3      Nikolskoye  59.7035   30.7861     -1.61        97           8
# 4           Galle   6.0367   80.2170     76.62        86          50
# 5      Bredasdorp -34.5322   20.0403     59.29        96         100
# 6     Port Alfred -33.5906   26.8910     68.22        92         100
# 7       Busselton -33.6500  115.3333     61.09        63          62
# 8           Dalby -27.1833  151.2667     74.10        58          57
# 9  Port Macquarie -31.4333  152.9167     71.89        69          99
#
#    Wind Speed Country                 Date
# 0       21.85      US  2021-12-05 23:34:24
# 1        2.89      GN  2021-12-05 23:34:24
# 2        9.40      PF  2021-12-05 23:32:19
# 3        4.54      RU  2021-12-05 23:34:25
# 4        4.43      LK  2021-12-05 23:34:25
# 5        8.48      ZA  2021-12-05 23:29:33
# 6       10.11      ZA  2021-12-05 23:32:30
# 7       17.65      AU  2021-12-05 23:34:27
# 8       15.05      AU  2021-12-05 23:34:27
# 9        6.20      AU  2021-12-05 23:29:35

# %%
#reorder the DaTAfRAME 
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]

#view cit_data_df
city_data_df
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        Barrow      US  2021-12-05 23:34:24  71.2906 -156.7887     12.22
# 1          Boke      GN  2021-12-05 23:34:24  10.9409  -14.2967     75.49
# 2       Rikitea      PF  2021-12-05 23:32:19 -23.1203 -134.9692     76.69
# 3    Nikolskoye      RU  2021-12-05 23:34:25  59.7035   30.7861     -1.61
# 4         Galle      LK  2021-12-05 23:34:25   6.0367   80.2170     76.62
# ..          ...     ...                  ...      ...       ...       ...
# 708  Launceston      AU  2021-12-05 23:50:09 -41.4500  147.1667     64.62
# 709      Ryotsu      JP  2021-12-05 23:54:20  38.0833  138.4333     39.16
# 710   Quelimane      MZ  2021-12-05 23:54:20 -17.8786   36.8883     80.55
# 711     Chapais      CA  2021-12-05 23:54:20  49.7834  -74.8492      1.18
# 712  Borogontsy      RU  2021-12-05 23:54:21  62.6683  131.1683    -15.09
#
#      Humidity  Cloudiness  Wind Speed
# 0          79          90       21.85
# 1          85          96        2.89
# 2          73          98        9.40
# 3          97           8        4.54
# 4          86          50        4.43
# ..        ...         ...         ...
# 708        66          75        7.00
# 709        66          20        3.02
# 710        83           0       14.00
# 711        98          95        4.05
# 712       100         100        4.29
#
# [713 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
